# %% [markdown]
# <a href="https://colab.research.google.com/github/mjwillis717-coder/dsrp/blob/main/DSRP_Education.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import pandas as pd

# %%
college_csv = '/content/College_Scorecard_Cleaned.csv'
college_df = pd.read_csv(college_csv)
college_df.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  LOCALE  \
# 0  100654             Alabama A & M University     AL       5    12.0
# 1  100663  University of Alabama at Birmingham     AL       5    12.0
# 2  100690                   Amridge University     AL       5    12.0
# 3  100706  University of Alabama in Huntsville     AL       5    12.0
# 4  100724             Alabama State University     AL       5    12.0
#
#    CONTROL  ADM_RATE  SAT_AVG  ACTCMMID     UGDS  COSTT4_A  TUITIONFEE_IN  \
# 0        1    0.5795    938.0      18.0   6124.0   27153.0        10024.0
# 1        1    0.8818   1258.0      27.0  11635.0   28145.0         9098.0
# 2        2       NaN      NaN       NaN    241.0       NaN         7590.0
# 3        1    0.6857   1319.0      28.0   6591.0   27392.0        12132.0
# 4        1    0.9755    976.0      18.0   3477.0   23586.0        11248.0
#
#    TUITIONFEE_OUT  PCTPELL  PCTFLOAN  RET_FT4  C150_4  GRAD_DEBT_MDN  \
# ...

# %%
college_df.columns
# Out:
# Index(['UNITID', 'INSTNM', 'STABBR', 'REGION', 'LOCALE', 'CONTROL', 'ADM_RATE',
#        'SAT_AVG', 'ACTCMMID', 'UGDS', 'COSTT4_A', 'TUITIONFEE_IN',
#        'TUITIONFEE_OUT', 'PCTPELL', 'PCTFLOAN', 'RET_FT4', 'C150_4',
#        'GRAD_DEBT_MDN', 'MD_EARN_WNE_4YR', 'MD_EARN_WNE_P10'],
#       dtype='object')

# %%
college_df.isnull().sum()
# Out:
# UNITID               0
# INSTNM               0
# STABBR               0
# REGION               0
# LOCALE               0
# CONTROL              0
# ADM_RATE           137
# SAT_AVG            572
# ACTCMMID           605
# UGDS                 0
# COSTT4_A            14
# TUITIONFEE_IN        0
# TUITIONFEE_OUT       0
# PCTPELL              0
# PCTFLOAN             0
# RET_FT4             11
# C150_4               9
# GRAD_DEBT_MDN        0
# MD_EARN_WNE_4YR     20
# MD_EARN_WNE_P10      0
# dtype: int64

# %%
college_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UNITID           1520 non-null   int64
#  1   INSTNM           1520 non-null   object
#  2   STABBR           1520 non-null   object
#  3   REGION           1520 non-null   int64
#  4   LOCALE           1520 non-null   float64
#  5   CONTROL          1520 non-null   int64
#  6   ADM_RATE         1383 non-null   float64
#  7   SAT_AVG          948 non-null    float64
#  8   ACTCMMID         915 non-null    float64
#  9   UGDS             1520 non-null   float64
#  10  COSTT4_A         1506 non-null   float64
#  11  TUITIONFEE_IN    1520 non-null   float64
#  12  TUITIONFEE_OUT   1520 non-null   float64
#  13  PCTPELL          1520 non-null   float64
#  14  PCTFLOAN         1520 non-null   float64
#  15  RET_FT4          1509 non-null   float64
# ...

# %%
college_df.describe()
# Out:
#               UNITID       REGION       LOCALE      CONTROL     ADM_RATE  \
# count    1520.000000  1520.000000  1520.000000  1520.000000  1383.000000
# mean   191617.030921     4.223026    20.309868     1.692105     0.712014
# std     64430.926875     2.122235    10.008589     0.525771     0.221358
# min    100654.000000     0.000000    11.000000     1.000000     0.036100
# 25%    153381.750000     2.000000    12.000000     1.000000     0.606050
# 50%    185417.000000     4.000000    21.000000     2.000000     0.760600
# 75%    217083.250000     5.000000    31.000000     2.000000     0.878500
# max    498571.000000     9.000000    43.000000     3.000000     1.000000
#
#            SAT_AVG    ACTCMMID           UGDS      COSTT4_A  TUITIONFEE_IN  \
# count   948.000000  915.000000    1520.000000   1506.000000    1520.000000
# mean   1187.740506   24.496175    5497.743421  43288.204515   28527.276974
# std     148.779356    4.195279   10122.501590  19785.297689   18591.580176
# ...

# %%
college_df['STABBR'].value_counts()
# Out:
# STABBR
# NY    113
# CA    100
# PA     89
# TX     75
# MA     65
# OH     60
# IL     57
# NC     53
# GA     45
# MO     45
# FL     43
# IN     41
# MI     40
# VA     39
# TN     39
# MN     36
# WI     33
# SC     33
# IA     29
# PR     29
# NJ     27
# KY     26
# AL     25
# MD     25
# KS     24
# OK     23
# LA     22
# CO     21
# WA     21
# AR     20
# CT     20
# OR     19
# NE     19
# ME     17
# WV     16
# MS     15
# NH     11
# AZ     11
# SD     11
# MT     10
# RI      9
# ND      9
# DC      9
# VT      9
# NM      7
# ID      6
# HI      6
# UT      6
# DE      4
# NV      3
# AK      2
# WY      1
# GU      1
# VI      1
# Name: count, dtype: int64

# %% [markdown]
# Data Cleaning

# %%
college_df = college_df.rename(columns={'UNITID': 'Unique Institutional ID', 'INSTNM':'Institution Name', 'STABBR':'State', 'REGION':'Region', 'LOCALE':'Campus Urbanization Type', 'CONTROL':'Institutional Control', 'ADM_RATE':'Admission Rate',
       'SAT_AVG':'Avearge SAT Score', 'ACTCMMID': 'Average ACT Midpoint', 'UGDS':'Undergarduate Enrollment', 'COSTT4_A':'Avearge Cost of Attendance', 'TUITIONFEE_IN':'Instate Tution',
       'TUITIONFEE_OUT':'Out of State Tution', 'PCTPELL':'Pell Grant Percentage', 'PCTFLOAN':'Federal Student Loan Percentage', 'RET_FT4':'Full-Time Retention Rate', 'C150_4':'Four-Year Institution Graduation Rate',
       'GRAD_DEBT_MDN':'Median Graduate Debt', 'MD_EARN_WNE_4YR':'Median Earnings 4 Years Post-Graduation', 'MD_EARN_WNE_P10':'Median Earnings 10 Years Post-Graduation'})
college_df.head()
# Out:
#    Unique Institutional ID                     Institution Name State  Region  \
# 0                   100654             Alabama A & M University    AL       5
# 1                   100663  University of Alabama at Birmingham    AL       5
# 2                   100690                   Amridge University    AL       5
# 3                   100706  University of Alabama in Huntsville    AL       5
# 4                   100724             Alabama State University    AL       5
#
#    Campus Urbanization Type  Institutional Control  Admission Rate  \
# 0                      12.0                      1          0.5795
# 1                      12.0                      1          0.8818
# 2                      12.0                      2             NaN
# 3                      12.0                      1          0.6857
# 4                      12.0                      1          0.9755
#
#    Avearge SAT Score  Average ACT Midpoint  Undergarduate Enrollment  \
# ...
